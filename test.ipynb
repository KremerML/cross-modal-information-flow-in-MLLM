# %%
x = [1,2,3,4,5,6,7]
k = 0
temp = x

# %%
x[:-k] = temp[-k:]
x[-k:] = temp[:-k]
x
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
temp[:-k]
# Out:
# []

# %%
[print(i) for i in range(1,5)]
# Out:
# 1
# 2
# 3
# 4
# [None, None, None, None]
